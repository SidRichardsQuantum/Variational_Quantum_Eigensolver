# %% [markdown]
# # ⚛️ H₂ Ground-State VQE — Noisy Optimizer Convergence (Pure Package Client)
#
# This notebook compares **optimizer convergence under noise** using only:
#
# ```python
# from vqe.core import run_vqe
# ```
#
# Workflow:
# 1) Run noisy VQE for each optimizer (single seed) and collect energy traces
# 2) Identify the *worst* optimizer (highest final energy)
# 3) Re-run the worst case and inspect dominant populations from diag(ρ)

# %%
import numpy as np
import matplotlib.pyplot as plt

from vqe.core import run_vqe

# %% [markdown]
# ## Configuration

# %%
molecule = "H2"
seed = 0

# Fixed ansatz across optimizers
ansatz_name = "UCCSD"

# Noise settings (intentionally exaggerated for visibility)
depolarizing_prob = 0.05
amplitude_damping_prob = 0.05

# Optimizer set + per-optimizer stepsize
optimizers = ["Adam", "GradientDescent", "Momentum", "Nesterov", "RMSProp", "Adagrad"]
steps = 75
stepsize_map = {
    "Adam": 0.2,
    "GradientDescent": 0.05,
    "Momentum": 0.1,
    "Nesterov": 0.1,
    "RMSProp": 0.1,
    "Adagrad": 0.2,
}

# Mapping if your run_vqe supports/needs it; keep constant for fair comparison.
mapping = "jordan_wigner"

print("Molecule:", molecule)
print("Seed:", seed)
print("Ansatz:", ansatz_name)
print("Steps:", steps)
print("Mapping:", mapping)
print("Noise: dep=", depolarizing_prob, " amp=", amplitude_damping_prob)
print("Optimizers:", optimizers)
# Out:
# Molecule: H2
# Seed: 0
# Ansatz: UCCSD
# Steps: 75
# Mapping: jordan_wigner
# Noise: dep= 0.05  amp= 0.05
# Optimizers: ['Adam', 'GradientDescent', 'Momentum', 'Nesterov', 'RMSProp', 'Adagrad']

# %% [markdown]
# ## Part 1 — Run noisy VQE for each optimizer (collect convergence)

# %%
traces = {}
final_energies = {}

for opt in optimizers:
    step = stepsize_map.get(opt, None)
    if step is None:
        raise KeyError(f"No stepsize provided for optimizer='{opt}'")

    r = run_vqe(
        molecule=molecule,
        ansatz_name=ansatz_name,
        optimizer_name=opt,
        steps=int(steps),
        stepsize=float(step),
        noisy=True,
        depolarizing_prob=float(depolarizing_prob),
        amplitude_damping_prob=float(amplitude_damping_prob),
        mapping=mapping,
        seed=int(seed),
        plot=False,
        force=False,
    )

    E_trace = [float(x) for x in r.get("energies", [])]
    if len(E_trace) == 0:
        raise RuntimeError(f"run_vqe returned no energies trace for optimizer='{opt}'")

    traces[opt] = E_trace
    final_energies[opt] = float(E_trace[-1])
# Out:
# Step 01/75: E = -0.980595 Ha
# Step 02/75: E = -0.981353 Ha
# Step 03/75: E = -0.982058 Ha
# Step 04/75: E = -0.982715 Ha
# Step 05/75: E = -0.983326 Ha
# Step 06/75: E = -0.983896 Ha
# Step 07/75: E = -0.984426 Ha
# Step 08/75: E = -0.984920 Ha
# Step 09/75: E = -0.985380 Ha
# Step 10/75: E = -0.985807 Ha
# Step 11/75: E = -0.986206 Ha
# Step 12/75: E = -0.986577 Ha
# Step 13/75: E = -0.986922 Ha
# Step 14/75: E = -0.987243 Ha
# Step 15/75: E = -0.987542 Ha
# Step 16/75: E = -0.987820 Ha
# Step 17/75: E = -0.988079 Ha
# Step 18/75: E = -0.988321 Ha
# Step 19/75: E = -0.988545 Ha
# Step 20/75: E = -0.988754 Ha
# Step 21/75: E = -0.988948 Ha
# Step 22/75: E = -0.989129 Ha
# Step 23/75: E = -0.989297 Ha
# Step 24/75: E = -0.989454 Ha
# Step 25/75: E = -0.989599 Ha
# Step 26/75: E = -0.989735 Ha
# Step 27/75: E = -0.989861 Ha
# Step 28/75: E = -0.989979 Ha
# Step 29/75: E = -0.990088 Ha
# Step 30/75: E = -0.990190 Ha
# Step 31/75: E = -0.990284 Ha
# Step 32/75: E = -0.990372 Ha
# Step 33/75: E = -0.990454 Ha
# Step 34/75: E = -0.990530 Ha
# Step 35/75: E = -0.990601 Ha
# Step 36/75: E = -0.990667 Ha
# Step 37/75: E = -0.990729 Ha
# Step 38/75: E = -0.990786 Ha
# Step 39/75: E = -0.990839 Ha
# Step 40/75: E = -0.990888 Ha
# Step 41/75: E = -0.990934 Ha
# Step 42/75: E = -0.990977 Ha
# Step 43/75: E = -0.991017 Ha
# Step 44/75: E = -0.991054 Ha
# Step 45/75: E = -0.991088 Ha
# Step 46/75: E = -0.991120 Ha
# Step 47/75: E = -0.991150 Ha
# Step 48/75: E = -0.991178 Ha
# Step 49/75: E = -0.991204 Ha
# Step 50/75: E = -0.991228 Ha
# Step 51/75: E = -0.991250 Ha
# Step 52/75: E = -0.991271 Ha
# Step 53/75: E = -0.991290 Ha
# Step 54/75: E = -0.991308 Ha
# Step 55/75: E = -0.991325 Ha
# Step 56/75: E = -0.991341 Ha
# Step 57/75: E = -0.991355 Ha
# Step 58/75: E = -0.991369 Ha
# Step 59/75: E = -0.991381 Ha
# Step 60/75: E = -0.991393 Ha
# Step 61/75: E = -0.991404 Ha
# Step 62/75: E = -0.991414 Ha
# Step 63/75: E = -0.991423 Ha
# Step 64/75: E = -0.991432 Ha
# Step 65/75: E = -0.991440 Ha
# Step 66/75: E = -0.991448 Ha
# Step 67/75: E = -0.991455 Ha
# Step 68/75: E = -0.991461 Ha
# Step 69/75: E = -0.991467 Ha
# Step 70/75: E = -0.991473 Ha
# Step 71/75: E = -0.991478 Ha
# Step 72/75: E = -0.991483 Ha
# Step 73/75: E = -0.991488 Ha
# Step 74/75: E = -0.991492 Ha
# Step 75/75: E = -0.991496 Ha
#
# 💾 Saved run record: H2_uccsd_gradientdescent_noisy_dep05_amp05_s0_6607c56a96f0.json
#
# Step 01/75: E = -0.980595 Ha
# Step 02/75: E = -0.982083 Ha
# Step 03/75: E = -0.984526 Ha
# Step 04/75: E = -0.987228 Ha
# Step 05/75: E = -0.989541 Ha
# Step 06/75: E = -0.991030 Ha
# Step 07/75: E = -0.991547 Ha
# Step 08/75: E = -0.991223 Ha
# Step 09/75: E = -0.990378 Ha
# Step 10/75: E = -0.989402 Ha
# Step 11/75: E = -0.988636 Ha
# Step 12/75: E = -0.988298 Ha
# Step 13/75: E = -0.988444 Ha
# Step 14/75: E = -0.988987 Ha
# Step 15/75: E = -0.989748 Ha
# Step 16/75: E = -0.990521 Ha
# Step 17/75: E = -0.991130 Ha
# Step 18/75: E = -0.991476 Ha
# Step 19/75: E = -0.991541 Ha
# Step 20/75: E = -0.991386 Ha
# Step 21/75: E = -0.991115 Ha
# Step 22/75: E = -0.990840 Ha
# Step 23/75: E = -0.990651 Ha
# Step 24/75: E = -0.990598 Ha
# Step 25/75: E = -0.990682 Ha
# Step 26/75: E = -0.990868 Ha
# Step 27/75: E = -0.991098 Ha
# Step 28/75: E = -0.991313 Ha
# Step 29/75: E = -0.991468 Ha
# Step 30/75: E = -0.991542 Ha
# Step 31/75: E = -0.991538 Ha
# Step 32/75: E = -0.991478 Ha
# Step 33/75: E = -0.991395 Ha
# Step 34/75: E = -0.991320 Ha
# Step 35/75: E = -0.991277 Ha
# Step 36/75: E = -0.991275 Ha
# Step 37/75: E = -0.991311 Ha
# Step 38/75: E = -0.991371 Ha
# Step 39/75: E = -0.991439 Ha
# Step 40/75: E = -0.991497 Ha
# Step 41/75: E = -0.991535 Ha
# Step 42/75: E = -0.991549 Ha
# Step 43/75: E = -0.991541 Ha
# Step 44/75: E = -0.991520 Ha
# Step 45/75: E = -0.991496 Ha
# Step 46/75: E = -0.991477 Ha
# Step 47/75: E = -0.991468 Ha
# Step 48/75: E = -0.991471 Ha
# Step 49/75: E = -0.991484 Ha
# Step 50/75: E = -0.991503 Ha
# Step 51/75: E = -0.991523 Ha
# Step 52/75: E = -0.991538 Ha
# Step 53/75: E = -0.991547 Ha
# Step 54/75: E = -0.991549 Ha
# Step 55/75: E = -0.991545 Ha
# Step 56/75: E = -0.991538 Ha
# Step 57/75: E = -0.991531 Ha
# Step 58/75: E = -0.991527 Ha
# Step 59/75: E = -0.991525 Ha
# Step 60/75: E = -0.991527 Ha
# Step 61/75: E = -0.991532 Ha
# Step 62/75: E = -0.991537 Ha
# Step 63/75: E = -0.991543 Ha
# Step 64/75: E = -0.991547 Ha
# Step 65/75: E = -0.991549 Ha
# Step 66/75: E = -0.991549 Ha
# Step 67/75: E = -0.991547 Ha
# Step 68/75: E = -0.991545 Ha
# Step 69/75: E = -0.991543 Ha
# Step 70/75: E = -0.991542 Ha
# Step 71/75: E = -0.991542 Ha
# Step 72/75: E = -0.991543 Ha
# Step 73/75: E = -0.991544 Ha
# Step 74/75: E = -0.991546 Ha
# Step 75/75: E = -0.991548 Ha
#
# 💾 Saved run record: H2_uccsd_momentum_noisy_dep05_amp05_s0_28e51cc67cf0.json
#
# Step 01/75: E = -0.980595 Ha
# Step 02/75: E = -0.983330 Ha
# Step 03/75: E = -0.986287 Ha
# Step 04/75: E = -0.988821 Ha
# Step 05/75: E = -0.990555 Ha
# Step 06/75: E = -0.991405 Ha
# Step 07/75: E = -0.991522 Ha
# Step 08/75: E = -0.991179 Ha
# Step 09/75: E = -0.990673 Ha
# Step 10/75: E = -0.990242 Ha
# Step 11/75: E = -0.990022 Ha
# Step 12/75: E = -0.990047 Ha
# Step 13/75: E = -0.990272 Ha
# Step 14/75: E = -0.990608 Ha
# Step 15/75: E = -0.990959 Ha
# Step 16/75: E = -0.991253 Ha
# Step 17/75: E = -0.991447 Ha
# Step 18/75: E = -0.991537 Ha
# Step 19/75: E = -0.991543 Ha
# Step 20/75: E = -0.991498 Ha
# Step 21/75: E = -0.991437 Ha
# Step 22/75: E = -0.991388 Ha
# Step 23/75: E = -0.991365 Ha
# Step 24/75: E = -0.991372 Ha
# Step 25/75: E = -0.991401 Ha
# Step 26/75: E = -0.991442 Ha
# Step 27/75: E = -0.991483 Ha
# Step 28/75: E = -0.991517 Ha
# Step 29/75: E = -0.991539 Ha
# Step 30/75: E = -0.991548 Ha
# Step 31/75: E = -0.991548 Ha
# Step 32/75: E = -0.991542 Ha
# Step 33/75: E = -0.991535 Ha
# Step 34/75: E = -0.991529 Ha
# Step 35/75: E = -0.991527 Ha
# Step 36/75: E = -0.991528 Ha
# Step 37/75: E = -0.991532 Ha
# Step 38/75: E = -0.991537 Ha
# Step 39/75: E = -0.991542 Ha
# Step 40/75: E = -0.991545 Ha
# Step 41/75: E = -0.991548 Ha
# Step 42/75: E = -0.991549 Ha
# Step 43/75: E = -0.991549 Ha
# Step 44/75: E = -0.991548 Ha
# Step 45/75: E = -0.991547 Ha
# Step 46/75: E = -0.991546 Ha
# Step 47/75: E = -0.991546 Ha
# Step 48/75: E = -0.991546 Ha
# Step 49/75: E = -0.991547 Ha
# Step 50/75: E = -0.991547 Ha
# Step 51/75: E = -0.991548 Ha
# Step 52/75: E = -0.991549 Ha
# Step 53/75: E = -0.991549 Ha
# Step 54/75: E = -0.991549 Ha
# Step 55/75: E = -0.991549 Ha
# Step 56/75: E = -0.991549 Ha
# Step 57/75: E = -0.991549 Ha
# Step 58/75: E = -0.991549 Ha
# Step 59/75: E = -0.991549 Ha
# Step 60/75: E = -0.991549 Ha
# Step 61/75: E = -0.991549 Ha
# Step 62/75: E = -0.991549 Ha
# Step 63/75: E = -0.991549 Ha
# Step 64/75: E = -0.991549 Ha
# Step 65/75: E = -0.991549 Ha
# Step 66/75: E = -0.991549 Ha
# Step 67/75: E = -0.991549 Ha
# Step 68/75: E = -0.991549 Ha
# Step 69/75: E = -0.991549 Ha
# Step 70/75: E = -0.991549 Ha
# Step 71/75: E = -0.991549 Ha
# Step 72/75: E = -0.991549 Ha
# Step 73/75: E = -0.991549 Ha
# Step 74/75: E = -0.991549 Ha
# Step 75/75: E = -0.991549 Ha
#
# 💾 Saved run record: H2_uccsd_nesterov_noisy_dep05_amp05_s0_2e4202d9707b.json
#
# Step 01/75: E = -0.980595 Ha
# Step 02/75: E = -0.984588 Ha
# Step 03/75: E = -0.990120 Ha
# Step 04/75: E = -0.968098 Ha
# Step 05/75: E = -0.990425 Ha
# Step 06/75: E = -0.991189 Ha
# Step 07/75: E = -0.991384 Ha
# Step 08/75: E = -0.991445 Ha
# Step 09/75: E = -0.991467 Ha
# Step 10/75: E = -0.991463 Ha
# Step 11/75: E = -0.991439 Ha
# Step 12/75: E = -0.991372 Ha
# Step 13/75: E = -0.991221 Ha
# Step 14/75: E = -0.990834 Ha
# Step 15/75: E = -0.990031 Ha
# Step 16/75: E = -0.988512 Ha
# Step 17/75: E = -0.987563 Ha
# Step 18/75: E = -0.986498 Ha
# Step 19/75: E = -0.987527 Ha
# Step 20/75: E = -0.988186 Ha
# Step 21/75: E = -0.989642 Ha
# Step 22/75: E = -0.990240 Ha
# Step 23/75: E = -0.990686 Ha
# Step 24/75: E = -0.990792 Ha
# Step 25/75: E = -0.990852 Ha
# Step 26/75: E = -0.990717 Ha
# Step 27/75: E = -0.990549 Ha
# Step 28/75: E = -0.990104 Ha
# Step 29/75: E = -0.989715 Ha
# Step 30/75: E = -0.989000 Ha
# Step 31/75: E = -0.988886 Ha
# Step 32/75: E = -0.988412 Ha
# Step 33/75: E = -0.988879 Ha
# Step 34/75: E = -0.988920 Ha
# Step 35/75: E = -0.989579 Ha
# Step 36/75: E = -0.989779 Ha
# Step 37/75: E = -0.990161 Ha
# Step 38/75: E = -0.990177 Ha
# Step 39/75: E = -0.990292 Ha
# Step 40/75: E = -0.990107 Ha
# Step 41/75: E = -0.990057 Ha
# Step 42/75: E = -0.989699 Ha
# Step 43/75: E = -0.989633 Ha
# Step 44/75: E = -0.989238 Ha
# Step 45/75: E = -0.989355 Ha
# Step 46/75: E = -0.989097 Ha
# Step 47/75: E = -0.989412 Ha
# Step 48/75: E = -0.989337 Ha
# Step 49/75: E = -0.989701 Ha
# Step 50/75: E = -0.989683 Ha
# Step 51/75: E = -0.989942 Ha
# Step 52/75: E = -0.989849 Ha
# Step 53/75: E = -0.989980 Ha
# Step 54/75: E = -0.989779 Ha
# Step 55/75: E = -0.989842 Ha
# Step 56/75: E = -0.989570 Ha
# Step 57/75: E = -0.989657 Ha
# Step 58/75: E = -0.989394 Ha
# Step 59/75: E = -0.989567 Ha
# Step 60/75: E = -0.989372 Ha
# Step 61/75: E = -0.989616 Ha
# Step 62/75: E = -0.989491 Ha
# Step 63/75: E = -0.989742 Ha
# Step 64/75: E = -0.989632 Ha
# Step 65/75: E = -0.989836 Ha
# Step 66/75: E = -0.989688 Ha
# Step 67/75: E = -0.989836 Ha
# Step 68/75: E = -0.989639 Ha
# Step 69/75: E = -0.989766 Ha
# Step 70/75: E = -0.989544 Ha
# Step 71/75: E = -0.989690 Ha
# Step 72/75: E = -0.989480 Ha
# Step 73/75: E = -0.989663 Ha
# Step 74/75: E = -0.989485 Ha
# Step 75/75: E = -0.989694 Ha
#
# 💾 Saved run record: H2_uccsd_rmsprop_noisy_dep05_amp05_s0_b0f557e65637.json
#
# Step 01/75: E = -0.980595 Ha
# Step 02/75: E = -0.991345 Ha
# Step 03/75: E = -0.991439 Ha
# Step 04/75: E = -0.982178 Ha
# Step 05/75: E = -0.991342 Ha
# Step 06/75: E = -0.991542 Ha
# Step 07/75: E = -0.991547 Ha
# Step 08/75: E = -0.991548 Ha
# Step 09/75: E = -0.991549 Ha
# Step 10/75: E = -0.991549 Ha
# Step 11/75: E = -0.991549 Ha
# Step 12/75: E = -0.991549 Ha
# Step 13/75: E = -0.991549 Ha
# Step 14/75: E = -0.991549 Ha
# Step 15/75: E = -0.991549 Ha
# Step 16/75: E = -0.991549 Ha
# Step 17/75: E = -0.991549 Ha
# Step 18/75: E = -0.991549 Ha
# Step 19/75: E = -0.991549 Ha
# Step 20/75: E = -0.991549 Ha
# Step 21/75: E = -0.991549 Ha
# Step 22/75: E = -0.991549 Ha
# Step 23/75: E = -0.991549 Ha
# Step 24/75: E = -0.991549 Ha
# Step 25/75: E = -0.991549 Ha
# Step 26/75: E = -0.991549 Ha
# Step 27/75: E = -0.991549 Ha
# Step 28/75: E = -0.991549 Ha
# Step 29/75: E = -0.991549 Ha
# Step 30/75: E = -0.991549 Ha
# Step 31/75: E = -0.991549 Ha
# Step 32/75: E = -0.991549 Ha
# Step 33/75: E = -0.991549 Ha
# Step 34/75: E = -0.991549 Ha
# Step 35/75: E = -0.991549 Ha
# Step 36/75: E = -0.991549 Ha
# Step 37/75: E = -0.991549 Ha
# Step 38/75: E = -0.991549 Ha
# Step 39/75: E = -0.991549 Ha
# Step 40/75: E = -0.991549 Ha
# Step 41/75: E = -0.991549 Ha
# Step 42/75: E = -0.991549 Ha
# Step 43/75: E = -0.991549 Ha
# Step 44/75: E = -0.991549 Ha
# Step 45/75: E = -0.991549 Ha
# Step 46/75: E = -0.991549 Ha
# Step 47/75: E = -0.991549 Ha
# Step 48/75: E = -0.991549 Ha
# Step 49/75: E = -0.991549 Ha
# Step 50/75: E = -0.991549 Ha
# Step 51/75: E = -0.991549 Ha
# Step 52/75: E = -0.991549 Ha
# Step 53/75: E = -0.991549 Ha
# Step 54/75: E = -0.991549 Ha
# Step 55/75: E = -0.991549 Ha
# Step 56/75: E = -0.991549 Ha
# Step 57/75: E = -0.991549 Ha
# Step 58/75: E = -0.991549 Ha
# Step 59/75: E = -0.991549 Ha
# Step 60/75: E = -0.991549 Ha
# Step 61/75: E = -0.991549 Ha
# Step 62/75: E = -0.991549 Ha
# Step 63/75: E = -0.991549 Ha
# Step 64/75: E = -0.991549 Ha
# Step 65/75: E = -0.991549 Ha
# Step 66/75: E = -0.991549 Ha
# Step 67/75: E = -0.991549 Ha
# Step 68/75: E = -0.991549 Ha
# Step 69/75: E = -0.991549 Ha
# Step 70/75: E = -0.991549 Ha
# Step 71/75: E = -0.991549 Ha
# Step 72/75: E = -0.991549 Ha
# Step 73/75: E = -0.991549 Ha
# Step 74/75: E = -0.991549 Ha
# Step 75/75: E = -0.991549 Ha
#
# 💾 Saved run record: H2_uccsd_adagrad_noisy_dep05_amp05_s0_c6b29ae3f47e.json

# %% [markdown]
# ## Part 2 — Plot convergence curves

# %%
plt.figure(figsize=(10, 6))
for opt in optimizers:
    plt.plot(traces[opt], label=opt)

plt.xlabel("Iteration")
plt.ylabel("Energy (Ha)")
plt.title(
    f"{molecule} — Noisy VQE Convergence by Optimizer (dep={depolarizing_prob}, amp={amplitude_damping_prob})"
)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 3 — Identify the worst optimizer (highest final energy)

# %%
worst_optimizer = max(final_energies, key=final_energies.get)

print("Final energies (Ha):")
for opt in optimizers:
    print(f"  {opt:>16s} : {final_energies[opt]: .10f}")

print(f"\nWorst optimizer under noise: {worst_optimizer}")
# Out:
# Final energies (Ha):
#               Adam : -0.9915442393
#    GradientDescent : -0.9914960536
#           Momentum : -0.9915475394
#           Nesterov : -0.9915488552
#            RMSProp : -0.9896935253
#            Adagrad : -0.9915488650
#
# Worst optimizer under noise: RMSProp

# %% [markdown]
# ## Part 4 — Re-run worst case and extract density matrix ρ
#
# Engines sometimes return the final mixed state under different keys across refactors.
# We extract robustly:
# - Prefer `final_rho_real`/`final_rho_imag` if present
# - Else fall back to `final_state_real`/`final_state_imag`
#
# Then we reshape to an `(N, N)` matrix if needed.

# %%
res = run_vqe(
    molecule=molecule,
    ansatz_name=ansatz_name,
    optimizer_name=worst_optimizer,
    steps=int(steps),
    stepsize=float(stepsize_map[worst_optimizer]),
    noisy=True,
    depolarizing_prob=float(depolarizing_prob),
    amplitude_damping_prob=float(amplitude_damping_prob),
    mapping=mapping,
    seed=int(seed),
    plot=False,
    force=False,
)

rho_r = None
rho_i = None

if "final_rho_real" in res and "final_rho_imag" in res:
    rho_r = np.array(res["final_rho_real"], dtype=float)
    rho_i = np.array(res["final_rho_imag"], dtype=float)
elif "final_state_real" in res and "final_state_imag" in res:
    rho_r = np.array(res["final_state_real"], dtype=float)
    rho_i = np.array(res["final_state_imag"], dtype=float)
else:
    raise KeyError(
        "Expected final density/state arrays in result. "
        "Looked for (final_rho_real/final_rho_imag) or (final_state_real/final_state_imag)."
    )

rho = rho_r + 1j * rho_i

# If returned flattened, reshape to square
if rho.ndim == 1:
    n = int(np.sqrt(rho.size))
    if n * n != rho.size:
        raise ValueError(f"Cannot reshape size={rho.size} to a square density matrix.")
    rho = rho.reshape((n, n))

if rho.shape[0] != rho.shape[1]:
    raise ValueError(f"Expected square density matrix; got shape={rho.shape}.")

num_wires = int(np.log2(rho.shape[0]))
print("ρ shape:", rho.shape, " -> wires:", num_wires)
# Out:
# ρ shape: (16, 16)  -> wires: 4

# %% [markdown]
# ## Part 5 — Dominant basis-state populations from diag(ρ)

# %%
diag = np.real(np.diag(rho))
diag = np.clip(diag, 0.0, None)

threshold = 1e-2
idx = np.where(diag > threshold)[0]

terms = [f"({diag[i]:.4f}|{i:0{num_wires}b}⟩)" for i in idx]
print(f"\nSignificant populations (diag(ρ) > {threshold:g}):")
print("  " + (" + ".join(terms) if terms else "(none above threshold)"))
# Out:
# Significant populations (diag(ρ) > 0.01):
#   (0.0700|0100⟩) + (0.0700|1000⟩) + (0.7867|1100⟩) + (0.0257|1101⟩) + (0.0257|1110⟩)

# %% [markdown]
# ## Part 6 — Plot populations

# %%
labels = [f"|{i:0{num_wires}b}⟩" for i in idx]
vals = diag[idx]

plt.figure(figsize=(10, 5))
plt.bar(labels, vals)
plt.xlabel("Basis state")
plt.ylabel("Population Re[diag(ρ)]")
plt.title(f"{molecule} — Noisy VQE Populations (Worst optimizer: {worst_optimizer})")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
