# %% [markdown]
# # SSVQE (Noiseless) Comparisons
#
# Pure package client for comparing SSVQE performance across:
#
# 1) Optimizers (for fixed ansatz, optimizer-specific step sizes)
# 2) Ansatzes   (for fixed optimizer)
# 3) Full grid  (all ansatz × optimizer combos)
# 4) Pick a "best" config using an explicit excited-state target policy
# 5) Validate top configs across multiple seeds (mean ± std)

# %%
from __future__ import annotations

from dataclasses import dataclass
from typing import Any, Dict, List, Optional, Sequence, Tuple

import numpy as np
import pennylane as qml

from vqe.hamiltonian import build_hamiltonian
from vqe.ssvqe import run_ssvqe

# %% [markdown]
# ## Configuration

# %%
# -----------------------------
# Problem / run configuration
# -----------------------------
molecule = "H2"
num_states = 2
basis = "sto-3g"
noisy = False

# Only used if noisy=True
depolarizing_prob = 0.0
amplitude_damping_prob = 0.0
noise_model = None

# SSVQE weights (None => default [1,2,3,...])
weights: Optional[Sequence[float]] = None

# Reference states policy:
# - None: run_ssvqe decides defaults (UCC => HF+excitations, otherwise computational basis).
# - Or pass explicit bitstrings of length n_wires.
reference_states = None

# Optimization budget
steps = 250
seed = 0

# -----------------------------
# Optimizer sweep configuration
# -----------------------------
optimizers = ["Adam", "GradientDescent", "Momentum", "Nesterov", "RMSProp", "Adagrad"]
stepsize_map = {
    "Adam": 0.2,
    "GradientDescent": 0.05,
    "Momentum": 0.1,
    "Nesterov": 0.1,
    "RMSProp": 0.1,
    "Adagrad": 0.2,
}

fixed_ansatz = "UCCSD"

# -----------------------------
# Ansatz sweep configuration
# -----------------------------
ansatzes = [
    "UCC-S",
    "UCC-D",
    "UCCSD",
    "Minimal",
    "RY-CZ",
    "TwoQubit-RY-CNOT",
    "StronglyEntanglingLayers",
]

fixed_optimizer = "Adam"
fixed_stepsize = stepsize_map[fixed_optimizer]

# -----------------------------
# "Best config" target policy
# -----------------------------
excited_target_mode = "first"  # "first" or "low_k"
excited_target_k = 6           # used only if mode="low_k"

# %% [markdown]
# ## Build Hamiltonian + exact spectrum benchmark

# %%
H, n_wires, symbols, coordinates, basis = build_hamiltonian(molecule)
Hmat = np.array(qml.matrix(H), dtype=float)
evals = np.sort(np.linalg.eigvalsh(Hmat))

print(f"Molecule: {molecule}")
print(f"Qubits:   {n_wires}")
print(f"Basis:    {basis}")
print("Exact lowest 10 eigenvalues (Ha):")
for i, e in enumerate(evals[:10]):
    print(f"#{i:>2}: {float(e): .10f}")
# Out:
# Molecule: H2
# Qubits:   4
# Basis:    STO-3G
# Exact lowest 10 eigenvalues (Ha):
# # 0: -1.1372701749
# # 1: -0.5387095807
# # 2: -0.5387095807
# # 3: -0.5324790143
# # 4: -0.5324790143
# # 5: -0.5324790143
# # 6: -0.4469857253
# # 7: -0.4469857253
# # 8: -0.1699013991
# # 9:  0.2378052722
# /tmp/ipykernel_78723/4255159041.py:2: ComplexWarning: Casting complex values to real discards the imaginary part
#   Hmat = np.array(qml.matrix(H), dtype=float)

# %% [markdown]
# ## Run wrapper + table printer

# %%
@dataclass(frozen=True)
class SSVQERow:
    ansatz: str
    optimizer: str
    stepsize: float
    E_final: Tuple[float, ...]  # length = num_states


def _run_ssvqe_final_energies(
    *,
    ansatz_name: str,
    optimizer_name: str,
    stepsize: float,
    seed: int,
) -> Tuple[float, ...]:
    """
    Run SSVQE once and return final energies for all states as a tuple.
    """
    out = run_ssvqe(
        molecule=molecule,
        num_states=num_states,
        weights=weights,
        ansatz_name=ansatz_name,
        optimizer_name=optimizer_name,
        steps=steps,
        stepsize=stepsize,
        seed=seed,
        noisy=noisy,
        depolarizing_prob=depolarizing_prob,
        amplitude_damping_prob=amplitude_damping_prob,
        noise_model=noise_model,
        reference_states=reference_states,
        plot=False,
        force=False,
    )

    energies_per_state = out["energies_per_state"]
    finals = tuple(float(traj[-1]) for traj in energies_per_state)
    return finals


def _print_rows(rows: Sequence[SSVQERow], *, title: str) -> None:
    if not rows:
        print(f"\n{title}\n(no rows)\n")
        return

    headers = ["Ansatz", "Optimizer", "Stepsize"] + [f"E{i} (Ha)" for i in range(num_states)]

    def fmt_row(r: SSVQERow) -> List[str]:
        parts = [r.ansatz, r.optimizer, f"{r.stepsize:g}"]
        parts += [f"{e:+.10f}" for e in r.E_final]
        return parts

    data = [fmt_row(r) for r in rows]
    widths = [len(h) for h in headers]
    for row in data:
        widths = [max(w, len(cell)) for w, cell in zip(widths, row)]

    print("\n" + title)
    line = "  ".join(h.ljust(w) for h, w in zip(headers, widths))
    print(line)
    print("-" * len(line))
    for row in data:
        print("  ".join(cell.ljust(w) for cell, w in zip(row, widths)))

# %% [markdown]
# ## 1) Optimizer comparison (fixed ansatz)

# %%
optimizer_rows: List[SSVQERow] = []

for opt in optimizers:
    ss = stepsize_map[opt]
    print(f"Running: ansatz={fixed_ansatz}, optimizer={opt}, stepsize={ss} ...")
    finals = _run_ssvqe_final_energies(
        ansatz_name=fixed_ansatz,
        optimizer_name=opt,
        stepsize=float(ss),
        seed=int(seed),
    )
    optimizer_rows.append(SSVQERow(fixed_ansatz, opt, float(ss), finals))

optimizer_rows_sorted = sorted(
    optimizer_rows,
    key=lambda r: r.E_final[1] if num_states > 1 else r.E_final[0],
)
_print_rows(optimizer_rows_sorted, title=f"SSVQE Optimizer Comparison (ansatz={fixed_ansatz})")
# Out:
# Running: ansatz=UCCSD, optimizer=Adam, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCCSD)_2states__Adam__SSVQE__noiseless__s0__2e31e2101bf8.json
# Running: ansatz=UCCSD, optimizer=GradientDescent, stepsize=0.05 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCCSD)_2states__GradientDescent__SSVQE__noiseless__s0__b6414c2924c8.json
# Running: ansatz=UCCSD, optimizer=Momentum, stepsize=0.1 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCCSD)_2states__Momentum__SSVQE__noiseless__s0__6945713dba0c.json
# Running: ansatz=UCCSD, optimizer=Nesterov, stepsize=0.1 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCCSD)_2states__Nesterov__SSVQE__noiseless__s0__f1bffdbc2a6c.json
# Running: ansatz=UCCSD, optimizer=RMSProp, stepsize=0.1 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCCSD)_2states__RMSProp__SSVQE__noiseless__s0__18062e6bacc5.json
# Running: ansatz=UCCSD, optimizer=Adagrad, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCCSD)_2states__Adagrad__SSVQE__noiseless__s0__c6c4c442d705.json
#
# SSVQE Optimizer Comparison (ansatz=UCCSD)
# Ansatz  Optimizer        Stepsize  E0 (Ha)        E1 (Ha)
# ---------------------------------------------------------------
# UCCSD   Adam             0.2       -0.3511902067  -1.1372701749
# UCCSD   Adagrad          0.2       -0.3511902127  -1.1372701688
# UCCSD   RMSProp          0.1       -0.3513887567  -1.1351036269
# UCCSD   Nesterov         0.1       -0.4105998968  -1.0758317834
# UCCSD   Momentum         0.1       -1.0219124814  -0.4658037943
# UCCSD   GradientDescent  0.05      -1.1372701749  -0.3511902067

# %% [markdown]
# ## 2) Ansatz comparison (fixed optimizer)

# %%
ansatz_rows: List[SSVQERow] = []

for ans in ansatzes:
    print(f"Running: ansatz={ans}, optimizer={fixed_optimizer}, stepsize={fixed_stepsize} ...")
    finals = _run_ssvqe_final_energies(
        ansatz_name=ans,
        optimizer_name=fixed_optimizer,
        stepsize=float(fixed_stepsize),
        seed=int(seed),
    )
    ansatz_rows.append(SSVQERow(ans, fixed_optimizer, float(fixed_stepsize), finals))

ansatz_rows_sorted = sorted(
    ansatz_rows,
    key=lambda r: r.E_final[1] if num_states > 1 else r.E_final[0],
)
_print_rows(ansatz_rows_sorted, title=f"SSVQE Ansatz Comparison (optimizer={fixed_optimizer})")
# Out:
# Running: ansatz=UCC-S, optimizer=Adam, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-S)_2states__Adam__SSVQE__noiseless__s0__0a5fde10f232.json
# Running: ansatz=UCC-D, optimizer=Adam, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-D)_2states__Adam__SSVQE__noiseless__s0__2e3c727d8740.json
# Running: ansatz=UCCSD, optimizer=Adam, stepsize=0.2 ...
# 📂 Using cached SSVQE result: /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCCSD)_2states__Adam__SSVQE__noiseless__s0__2e31e2101bf8.json
# Running: ansatz=Minimal, optimizer=Adam, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(Minimal)_2states__Adam__SSVQE__noiseless__s0__2cb984a22aec.json
# Running: ansatz=RY-CZ, optimizer=Adam, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(RY-CZ)_2states__Adam__SSVQE__noiseless__s0__6b75bdd860cd.json
# Running: ansatz=TwoQubit-RY-CNOT, optimizer=Adam, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(TwoQubit-RY-CNOT)_2states__Adam__SSVQE__noiseless__s0__d873e1cdb2ff.json
# Running: ansatz=StronglyEntanglingLayers, optimizer=Adam, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(StronglyEntanglingLayers)_2states__Adam__SSVQE__noiseless__s0__2313f25ef8a8.json
#
# SSVQE Ansatz Comparison (optimizer=Adam)
# Ansatz                    Optimizer  Stepsize  E0 (Ha)        E1 (Ha)
# ---------------------------------------------------------------------------
# UCCSD                     Adam       0.2       -0.3511902067  -1.1372701749
# StronglyEntanglingLayers  Adam       0.2       -0.5324790143  -1.1372701749
# UCC-S                     Adam       0.2       -0.3511902067  -1.1166843872
# RY-CZ                     Adam       0.2       -0.4469673464  -1.1166753839
# TwoQubit-RY-CNOT          Adam       0.2       -0.5188348323  -0.5703580047
# Minimal                   Adam       0.2       -1.1166843872  -0.4469857253
# UCC-D                     Adam       0.2       -1.1372701749  -0.3511902067

# %% [markdown]
# ## 3) Full grid (all ansatz × optimizer combos)

# %%
grid_rows: List[SSVQERow] = []

for ans in ansatzes:
    for opt in optimizers:
        ss = stepsize_map[opt]
        print(f"Running: ansatz={ans}, optimizer={opt}, stepsize={ss} ...")
        finals = _run_ssvqe_final_energies(
            ansatz_name=ans,
            optimizer_name=opt,
            stepsize=float(ss),
            seed=int(seed),
        )
        grid_rows.append(SSVQERow(ans, opt, float(ss), finals))

grid_rows_sorted = sorted(
    grid_rows,
    key=lambda r: (r.E_final[1] if num_states > 1 else r.E_final[0], r.E_final[0]),
)
_print_rows(grid_rows_sorted, title="SSVQE Full Grid (all ansatz × optimizer combos)")
# Out:
# Running: ansatz=UCC-S, optimizer=Adam, stepsize=0.2 ...
# 📂 Using cached SSVQE result: /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-S)_2states__Adam__SSVQE__noiseless__s0__0a5fde10f232.json
# Running: ansatz=UCC-S, optimizer=GradientDescent, stepsize=0.05 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-S)_2states__GradientDescent__SSVQE__noiseless__s0__be831ecd1c8c.json
# Running: ansatz=UCC-S, optimizer=Momentum, stepsize=0.1 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-S)_2states__Momentum__SSVQE__noiseless__s0__a98efa817111.json
# Running: ansatz=UCC-S, optimizer=Nesterov, stepsize=0.1 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-S)_2states__Nesterov__SSVQE__noiseless__s0__9e9b504e416d.json
# Running: ansatz=UCC-S, optimizer=RMSProp, stepsize=0.1 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-S)_2states__RMSProp__SSVQE__noiseless__s0__77bb5c7ae544.json
# Running: ansatz=UCC-S, optimizer=Adagrad, stepsize=0.2 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-S)_2states__Adagrad__SSVQE__noiseless__s0__ae56ca643766.json
# Running: ansatz=UCC-D, optimizer=Adam, stepsize=0.2 ...
# 📂 Using cached SSVQE result: /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-D)_2states__Adam__SSVQE__noiseless__s0__2e3c727d8740.json
# Running: ansatz=UCC-D, optimizer=GradientDescent, stepsize=0.05 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-D)_2states__GradientDescent__SSVQE__noiseless__s0__37d8cf595f37.json
# Running: ansatz=UCC-D, optimizer=Momentum, stepsize=0.1 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-D)_2states__Momentum__SSVQE__noiseless__s0__76ea8cca17bd.json
# Running: ansatz=UCC-D, optimizer=Nesterov, stepsize=0.1 ...
# 💾 Saved SSVQE run to /workspaces/Variational_Quantum_Eigensolver/results/vqe/H2__SSVQE(UCC-D)_2states__Nesterov__SSVQE__noiseless__s0__1436e30b7ec5.json
# Running: ansatz=UCC-D, optimizer=RMSProp, stepsize=0.1 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       5         ss = stepsize_map[opt]
#       6         print(f"Running: ansatz={ans}, optimizer={opt}, stepsize={ss} ...")
# ----> 7         finals = _run_ssvqe_final_energies(
#       8             ansatz_name=ans,
#       9             optimizer_name=opt,
#      10             stepsize=float(ss),
#      11             seed=int(seed),
#      12         )
#      13         grid_rows.append(SSVQERow(ans, opt, float(ss), finals))
#      15 grid_rows_sorted = sorted(
#      16     grid_rows,
#      17     key=lambda r: (r.E_final[1] if num_states > 1 else r.E_final[0], r.E_final[0]),
#      18 )
#
# Cell In[4], line 19, in _run_ssvqe_final_energies(ansatz_name, optimizer_name, stepsize, seed)
#       9 def _run_ssvqe_final_energies(
#      10     *,
#      11     ansatz_name: str,
#    (...)     14     seed: int,
#      15 ) -> Tuple[float, ...]:
#      16     """
#      17     Run SSVQE once and return final energies for all states as a tuple.
#      18     """
# ---> 19     out = run_ssvqe(
#      20         molecule=molecule,
#      21         num_states=num_states,
#      22         weights=weights,
#      23         ansatz_name=ansatz_name,
#      24         optimizer_name=optimizer_name,
#      25         steps=steps,
#      26         stepsize=stepsize,
#      27         seed=seed,
#      28         noisy=noisy,
#      29         depolarizing_prob=depolarizing_prob,
#      30         amplitude_damping_prob=amplitude_damping_prob,
#      31         noise_model=noise_model,
#      32         reference_states=reference_states,
#      33         plot=False,
#      34         force=False,
#      35     )
#      37     energies_per_state = out["energies_per_state"]
#      38     finals = tuple(float(traj[-1]) for traj in energies_per_state)
#
# File /workspaces/Variational_Quantum_Eigensolver/vqe/ssvqe.py:354, in run_ssvqe(molecule, num_states, weights, ansatz_name, optimizer_name, steps, stepsize, seed, noisy, depolarizing_prob, amplitude_damping_prob, noise_model, symbols, coordinates, basis, reference_states, plot, force)
#     352 for _ in range(int(steps)):
#     353     try:
# --> 354         params, _ = opt.step_and_cost(cost, params)
#     355     except AttributeError:
#     356         params = opt.step(cost, params)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/optimize/gradient_descent.py:64, in GradientDescentOptimizer.step_and_cost(self, objective_fn, grad_fn, *args, **kwargs)
#      44 def step_and_cost(self, objective_fn, *args, grad_fn=None, **kwargs):
#      45     """Update trainable arguments with one step of the optimizer and return the corresponding
#      46     objective function value prior to the step.
#      47
#    (...)     61         If single arg is provided, list [array] is replaced by array.
#      62     """
# ---> 64     g, forward = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#      65     new_args = self.apply_grad(g, args)
#      67     if forward is None:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/optimize/gradient_descent.py:122, in GradientDescentOptimizer.compute_grad(objective_fn, args, kwargs, grad_fn)
#     104 r"""Compute the gradient of the objective function at the given point and return it along with
#     105 the objective function forward pass (if available).
#     106
#    (...)    119     will not be evaluated and instead ``None`` will be returned.
#     120 """
#     121 g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 122 grad = g(*args, **kwargs)
#     123 forward = getattr(g, "forward", None)
#     125 num_trainable_args = sum(getattr(arg, "requires_grad", False) for arg in args)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/_grad.py:318, in grad.__call__(self, *args, **kwargs)
#     315     self._forward = self._fun(*args, **kwargs)
#     316     return ()
# --> 318 grad_value, ans = grad_fn(*args, **kwargs)  # pylint: disable=not-callable
#     319 self._forward = ans
#     321 return grad_value
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/autograd/wrap_util.py:23, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      21 else:
#      22     x = tuple(args[i] for i in argnum)
# ---> 23 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/_grad.py:344, in grad._grad_with_forward(fun, x)
#     338 if vspace(ans).size != 1:
#     339     raise TypeError(
#     340         "Grad only applies to real scalar-output functions. "
#     341         "Try jacobian, elementwise_grad or holomorphic_grad."
#     342     )
# --> 344 grad_value = vjp(vspace(ans).ones())
#     345 return grad_value, ans
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/autograd/core.py:20, in make_vjp.<locals>.vjp(g)
#      19 def vjp(g):
# ---> 20     return backward_pass(g, end_node)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/autograd/core.py:29, in backward_pass(g, end_node)
#      27 for node in toposort(end_node):
#      28     outgrad = outgrads.pop(node)
# ---> 29     ingrads = node.vjp(outgrad[0])
#      30     for parent, ingrad in zip(node.parents, ingrads):
#      31         outgrads[parent] = add_outgrads(outgrads.get(parent), ingrad)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/autograd/core.py:83, in defvjp.<locals>.vjp_argnums.<locals>.<lambda>(g)
#      81         raise NotImplementedError(f"VJP of {fun.__name__} wrt argnum 0 not defined")
#      82     vjp = vjpfun(ans, *args, **kwargs)
# ---> 83     return lambda g: (vjp(g),)
#      84 elif L == 2:
#      85     argnum_0, argnum_1 = argnums
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/workflow/interfaces/autograd.py:215, in vjp.<locals>.grad_fn(dy)
#     212 def grad_fn(dy):
#     213     """Returns the vector-Jacobian product with given
#     214     parameter values and output gradient dy"""
# --> 215     vjps = jpc.compute_vjp(tapes, dy)
#     216     return tuple(
#     217         qml.math.to_numpy(v, max_depth=1) if isinstance(v, ArrayBox) else v for v in vjps
#     218     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/workflow/jacobian_products.py:324, in TransformJacobianProducts.compute_vjp(self, tapes, dy)
#     321     logger.debug("compute_vjp called with (%s, %s)", tapes, dy)
#     323 if self._cache_full_jacobian:
# --> 324     jacs = self.compute_jacobian(tapes)
#     325     return _compute_vjps(jacs, dy, tapes)
#     327 vjp_tapes, processing_fn = qml.gradients.batch_vjp(
#     328     tapes, dy, self._gradient_transform, gradient_kwargs=self._gradient_kwargs
#     329 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/workflow/jacobian_products.py:354, in TransformJacobianProducts.compute_jacobian(self, tapes)
#     352 if tapes in self._cache:
#     353     return self._cache[tapes]
# --> 354 jac_tapes, batch_post_processing = self._gradient_transform(tapes, **self._gradient_kwargs)
#     355 results = self._inner_execute(jac_tapes)
#     356 jacs = tuple(batch_post_processing(results))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/transforms/core/transform_dispatcher.py:281, in TransformDispatcher.__call__(self, *targs, **tkwargs)
#     278     return self._qfunc_transform(obj, targs, tkwargs)
#     280 if isinstance(obj, Sequence) and all(isinstance(q, qml.tape.QuantumScript) for q in obj):
# --> 281     return self._batch_transform(obj, targs, tkwargs)
#     283 # Input is not a QNode nor a quantum tape nor a device.
#     284 # Assume Python decorator syntax:
#     285 #
#     286 # result = some_transform(*transform_args)(qnode)(*qnode_args)
#     288 raise TransformError(
#     289     "Decorating a QNode with @transform_fn(**transform_kwargs) has been "
#     290     "removed. Please decorate with @functools.partial(transform_fn, **transform_kwargs) "
#    (...)    293     "https://docs.pennylane.ai/en/stable/development/deprecations.html#completed-deprecation-cycles",
#     294 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/transforms/core/transform_dispatcher.py:489, in TransformDispatcher._batch_transform(self, original_batch, targs, tkwargs)
#     483 tape_counts = []
#     485 for t in original_batch:
#     486     # Preprocess the tapes by applying transforms
#     487     # to each tape, and storing corresponding tapes
#     488     # for execution, processing functions, and list of tape lengths.
# --> 489     new_tapes, fn = self(t, *targs, **tkwargs)
#     490     execution_tapes.extend(new_tapes)
#     491     batch_fns.append(fn)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/transforms/core/transform_dispatcher.py:240, in TransformDispatcher.__call__(self, *targs, **tkwargs)
#     238 start = 0
#     239 for tape in expanded_tapes:
# --> 240     intermediate_tapes, post_processing_fn = self._transform(
#     241         tape, *targs, **tkwargs
#     242     )
#     243     transformed_tapes.extend(intermediate_tapes)
#     244     end = start + len(intermediate_tapes)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/gradients/parameter_shift.py:1165, in param_shift(tape, argnum, shifts, gradient_recipes, fallback_fn, f0, broadcast)
#    1163     g_tapes, fn = var_param_shift(tape, argnum, shifts, gradient_recipes, f0, broadcast)
#    1164 else:
# -> 1165     g_tapes, fn = expval_param_shift(tape, argnum, shifts, gradient_recipes, f0, broadcast)
#    1167 gradient_tapes.extend(g_tapes)
#    1169 if unsupported_params:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/gradients/parameter_shift.py:406, in expval_param_shift(tape, argnum, shifts, gradient_recipes, f0, broadcast)
#     401 recipe, at_least_one_unshifted, unshifted_coeff = _extract_unshifted(
#     402     recipe, at_least_one_unshifted, f0, gradient_tapes, tape
#     403 )
#     404 coeffs, multipliers, op_shifts = recipe.T
# --> 406 g_tapes = generate_shifted_tapes(tape, idx, op_shifts, multipliers, broadcast)
#     407 gradient_tapes.extend(g_tapes)
#     408 # If broadcast=True, g_tapes only contains one tape. If broadcast=False, all returned
#     409 # tapes will have the same batch_size=None. Thus we only use g_tapes[0].batch_size here.
#     410 # If no gradient tapes are returned (e.g. only unshifted term in recipe), batch_size=None
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/gradients/general_shift_rules.py:467, in generate_shifted_tapes(tape, index, shifts, multipliers, broadcast)
#     464 if broadcast:
#     465     return (_copy_and_shift_params(tape, [index], [shifts], [multipliers]),)
# --> 467 return tuple(
#     468     _copy_and_shift_params(tape, [index], [shift], [multiplier])
#     469     for shift, multiplier in zip(shifts, multipliers)
#     470 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/gradients/general_shift_rules.py:468, in <genexpr>(.0)
#     464 if broadcast:
#     465     return (_copy_and_shift_params(tape, [index], [shifts], [multipliers]),)
#     467 return tuple(
# --> 468     _copy_and_shift_params(tape, [index], [shift], [multiplier])
#     469     for shift, multiplier in zip(shifts, multipliers)
#     470 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/gradients/general_shift_rules.py:413, in _copy_and_shift_params(tape, indices, shifts, multipliers, cast)
#     411     multiplier = math.cast_like(multiplier, new_params[p_idx])
#     412     shift = math.convert_like(shift, new_params[p_idx])
# --> 413     shift = math.cast_like(shift, new_params[p_idx])
#     414 new_params[p_idx] = new_params[p_idx] * multiplier
#     415 new_params[p_idx] = new_params[p_idx] + shift
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/math/utils.py:294, in cast_like(tensor1, tensor2)
#     292 else:
#     293     dtype = tensor2.dtype
# --> 294 return cast(tensor1, dtype)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pennylane/math/utils.py:261, in cast(tensor, dtype)
#     259 if not isinstance(dtype, str):
#     260     try:
# --> 261         dtype = np.dtype(dtype).name
#     262     except (AttributeError, TypeError, ImportError):
#     263         dtype = getattr(dtype, "name", dtype)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/core/_dtype.py:362, in _name_get(dtype)
#     359     name = _kind_name(dtype)
#     361 # append bit counts
# --> 362 if _name_includes_bit_suffix(dtype):
#     363     name += "{}".format(dtype.itemsize * 8)
#     365 # append metadata to datetimes
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/core/_dtype.py:339, in _name_includes_bit_suffix(dtype)
#     337 elif dtype.type is None:
#     338     return True
# --> 339 elif np.issubdtype(dtype, np.flexible) and _isunsized(dtype):
#     340     # unspecified
#     341     return False
#     342 else:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/core/numerictypes.py:417, in issubdtype(arg1, arg2)
#     359 r"""
#     360 Returns True if first argument is a typecode lower/equal in type hierarchy.
#     361
#    (...)    414
#     415 """
#     416 if not issubclass_(arg1, generic):
# --> 417     arg1 = dtype(arg1).type
#     418 if not issubclass_(arg2, generic):
#     419     arg2 = dtype(arg2).type
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4) Choose the "best" configuration
#
# Definitions:
# - $ΔE_0 = |E_0 - \text{exact}[0]|$
# - $ΔE_1$ depends on `excited_target_mode`:
#     * "first": $|E_1 - \text{exact}[1]|$
#     * "low_k": $min_{1\leq j \leq k} |E_1 - \text{exact}[j]|$
#
# Score: $ΔE_0 + ΔE_1$

# %%
def _excited_error(E1: float, exact: np.ndarray) -> float:
    if len(exact) < 2:
        return float("nan")

    mode = str(excited_target_mode).strip().lower()
    if mode == "first":
        return float(abs(E1 - float(exact[1])))

    if mode == "low_k":
        k = max(1, int(excited_target_k))
        tgt = exact[1 : 1 + k]
        return float(np.min(np.abs(tgt - E1)))

    raise ValueError("excited_target_mode must be 'first' or 'low_k'.")


def _score_row(r: SSVQERow, exact: np.ndarray) -> Dict[str, Any]:
    E0 = float(r.E_final[0])
    E1 = float(r.E_final[1]) if len(r.E_final) > 1 else float("nan")
    dE0 = abs(E0 - float(exact[0]))
    dE1 = _excited_error(E1, exact)
    return {
        "row": r,
        "E0": E0,
        "E1": E1,
        "dE0": dE0,
        "dE1": dE1,
        "score": dE0 + dE1,
    }


scored = [_score_row(r, evals) for r in grid_rows]
scored_sorted = sorted(scored, key=lambda x: (x["score"], x["dE1"], x["dE0"]))

best = scored_sorted[0]
rbest: SSVQERow = best["row"]

print(f"\nTarget policy: excited_target_mode={excited_target_mode!r}, excited_target_k={excited_target_k}")
print("\nBest configuration:")
print(f"  Ansatz:    {rbest.ansatz}")
print(f"  Optimizer: {rbest.optimizer}")
print(f"  Stepsize:  {rbest.stepsize:g}")
print(f"  E0_final:  {best['E0']:+.10f}   (ΔE0={best['dE0']:.3e} Ha)")
print(f"  E1_final:  {best['E1']:+.10f}   (ΔE1={best['dE1']:.3e} Ha)")
print(f"  Score:     {best['score']:.3e}")

top_k = 10
print(f"\nTop {top_k} configurations:")
for i, x in enumerate(scored_sorted[:top_k], start=1):
    rr: SSVQERow = x["row"]
    print(
        f"{i:>2}. ansatz={rr.ansatz:<22} optimizer={rr.optimizer:<14} stepsize={rr.stepsize:<5g}  "
        f"E0={x['E0']:+.10f} (ΔE0={x['dE0']:.2e})  "
        f"E1={x['E1']:+.10f} (ΔE1={x['dE1']:.2e})  "
        f"score={x['score']:.2e}"
    )

# %% [markdown]
# ## 5) Validate top configurations across multiple seeds (mean ± std)

# %%
seeds = np.arange(5)
top_k_validate = 5

top_configs = scored_sorted[:top_k_validate]

def _mean_std(xs: Sequence[float]) -> Tuple[float, float]:
    a = np.asarray(xs, dtype=float)
    if len(a) <= 1:
        return float(a.mean()), 0.0
    return float(a.mean()), float(a.std(ddof=1))


val_rows: List[Dict[str, Any]] = []

for i, x in enumerate(top_configs, start=1):
    rr: SSVQERow = x["row"]

    E0s: List[float] = []
    E1s: List[float] = []
    dE0s: List[float] = []
    dE1s: List[float] = []

    print(f"\nValidating {i}/{len(top_configs)}: ansatz={rr.ansatz}, optimizer={rr.optimizer}, stepsize={rr.stepsize:g}, seeds={seeds}")

    for s in seeds:
        finals = _run_ssvqe_final_energies(
            ansatz_name=rr.ansatz,
            optimizer_name=rr.optimizer,
            stepsize=float(rr.stepsize),
            seed=int(s),
        )
        E0 = float(finals[0])
        E1 = float(finals[1]) if len(finals) > 1 else float("nan")

        E0s.append(E0)
        E1s.append(E1)
        dE0s.append(abs(E0 - float(evals[0])))
        dE1s.append(_excited_error(E1, evals))

    E0_mean, E0_std = _mean_std(E0s)
    E1_mean, E1_std = _mean_std(E1s)
    dE0_mean, dE0_std = _mean_std(dE0s)
    dE1_mean, dE1_std = _mean_std(dE1s)

    val_rows.append(
        {
            "ansatz": rr.ansatz,
            "optimizer": rr.optimizer,
            "stepsize": rr.stepsize,
            "E0_mean": E0_mean,
            "E0_std": E0_std,
            "E1_mean": E1_mean,
            "E1_std": E1_std,
            "dE0_mean": dE0_mean,
            "dE0_std": dE0_std,
            "dE1_mean": dE1_mean,
            "dE1_std": dE1_std,
            "score_mean": dE0_mean + dE1_mean,
        }
    )

val_rows_sorted = sorted(val_rows, key=lambda r: (r["score_mean"], r["dE1_std"], r["dE0_std"]))

print("\nMulti-seed validation summary (sorted by mean score):")
hdr = (
    f"{'Ansatz':<22}  {'Optimizer':<14}  {'SS':<5}  "
    f"{'E0 mean±std':<26}  {'E1 mean±std':<26}  "
    f"{'ΔE0 mean±std':<26}  {'ΔE1 mean±std':<26}  {'score_mean':<10}"
)
print(hdr)
print("-" * len(hdr))

for r in val_rows_sorted:
    print(
        f"{r['ansatz']:<22}  {r['optimizer']:<14}  {r['stepsize']:<5g}  "
        f"{r['E0_mean']:+.10f}±{r['E0_std']:.2e}  "
        f"{r['E1_mean']:+.10f}±{r['E1_std']:.2e}  "
        f"{r['dE0_mean']:.2e}±{r['dE0_std']:.2e}  "
        f"{r['dE1_mean']:.2e}±{r['dE1_std']:.2e}  "
        f"{r['score_mean']:.2e}"
    )

best_mean = val_rows_sorted[0]
print("\nBest configuration by mean score across seeds:")
print(f"  Ansatz:    {best_mean['ansatz']}")
print(f"  Optimizer: {best_mean['optimizer']}")
print(f"  Stepsize:  {best_mean['stepsize']}")
print(f"  E0:        {best_mean['E0_mean']:+.10f} ± {best_mean['E0_std']:.2e}")
print(f"  E1:        {best_mean['E1_mean']:+.10f} ± {best_mean['E1_std']:.2e}")
print(f"  ΔE0:       {best_mean['dE0_mean']:.2e} ± {best_mean['dE0_std']:.2e}")
print(f"  ΔE1:       {best_mean['dE1_mean']:.2e} ± {best_mean['dE1_std']:.2e}")
print(f"  score:     {best_mean['score_mean']:.2e}")
